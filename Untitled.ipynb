# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', 20)

# %%
astr_df = pd.read_csv('astronauts.csv')
spacewalks_df = pd.read_csv('space_walks.csv')
spacemissions_df = pd.read_csv('space_missions.csv')
global_launches_df = pd.read_csv('global_space_launches.csv')

# %%
spacemissions_df = spacemissions_df.drop(labels=['Unnamed: 0', 'Unnamed: 0.1'], axis=1)

# %%
mg= global_launches_df.merge(spacemissions_df)

# %%
astr_df
# Out:
#                       Name    Year  Group   Status Birth Date  \
# 0          Joseph M. Acaba  2004.0   19.0   Active  5/17/1967
# 1           Loren W. Acton     NaN    NaN  Retired   3/7/1936
# 2         James C. Adamson  1984.0   10.0  Retired   3/3/1946
# 3          Thomas D. Akers  1987.0   12.0  Retired  5/20/1951
# 4              Buzz Aldrin  1963.0    3.0  Retired  1/20/1930
# ..                     ...     ...    ...      ...        ...
# 352          David A. Wolf  1990.0   13.0  Retired  8/23/1956
# 353  Neil W. Woodward III   1998.0   17.0  Retired  7/26/1962
# 354       Alfred M. Worden  1966.0    5.0  Retired   2/7/1932
# 355          John W. Young  1962.0    2.0  Retired  9/24/1930
# 356        George D. Zamka  1998.0   17.0  Retired  6/29/1962
#
#            Birth Place Gender  \
# 0        Inglewood, CA   Male
# 1         Lewiston, MT   Male
# 2           Warsaw, NY   Male
# 3        St. Louis, MO   Male
# 4        Montclair, NJ   Male
# ..                 ...    ...
# ...

# %%
del spacewalks_df["EVA #"]
spacewalks_df
# Out:
#     Country                                  Crew      Vehicle  \
# 0       USA                              Ed White    Gemini IV
# 1       USA                           David Scott  Gemini VIII
# 2       USA                         Eugene Cernan  Gemini IX-A
# 3       USA                          Mike Collins     Gemini X
# 4       USA                          Mike Collins     Gemini X
# ..      ...                                   ...          ...
# 369  Russia       Oleg Kononenko|Anton Shkaplerov  ISS Incr-30
# 370  Russia      Gennady Padalka|Yuri Malenchenko  ISS Incr-32
# 371  Russia      Pavel Vinogradov|Roman Romanenko  ISS Incr-35
# 372  Russia  Fyodor Yurchikhin|Alexander Misurkin  ISS Incr-36
# 373  Russia  Fyodor Yurchikhin|Alexander Misurkin  ISS Incr-36
#
#                   Date Duration  \
# 0           06/03/1965     0:36
# 1    March 16-17, 1966     0:00
# 2           06/05/1966     2:07
# 3           07/19/1966     0:50
# 4           07/20/1966     0:39
# ...

# %%
spacemissions_df
# Out:
#      Company Name                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                            Datum  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# ...

# %%
global_launches_df
# Out:
#      Company Name                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1           CASIC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                                             Detail  Status Rocket  Rocket  \
# ...

# %%
mg
# Out:
#      Company Name                                      Location  \
# 0          SpaceX    LC-39A, Kennedy Space Center, Florida, USA
# 1          SpaceX                 Pad A, Boca Chica, Texas, USA
# 2       Roscosmos  Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 3             ULA      SLC-41, Cape Canaveral AFS, Florida, USA
# 4       Roscosmos    Site 31/6, Baikonur Cosmodrome, Kazakhstan
# ...           ...                                           ...
# 4190      US Navy      LC-18A, Cape Canaveral AFS, Florida, USA
# 4191         AMBA      LC-26A, Cape Canaveral AFS, Florida, USA
# 4192      US Navy      LC-18A, Cape Canaveral AFS, Florida, USA
# 4193    RVSN USSR     Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4194    RVSN USSR     Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                                             Detail  Status Rocket  Rocket  \
# 0     Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.0
# ...

# %%
mg= mg.drop(labels=['DateTime', 'Year', 'Month', 'Day', 'Datum'], axis=1)
mg
# Out:
#      Company Name                                      Location  \
# 0          SpaceX    LC-39A, Kennedy Space Center, Florida, USA
# 1          SpaceX                 Pad A, Boca Chica, Texas, USA
# 2       Roscosmos  Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 3             ULA      SLC-41, Cape Canaveral AFS, Florida, USA
# 4       Roscosmos    Site 31/6, Baikonur Cosmodrome, Kazakhstan
# ...           ...                                           ...
# 4190      US Navy      LC-18A, Cape Canaveral AFS, Florida, USA
# 4191         AMBA      LC-26A, Cape Canaveral AFS, Florida, USA
# 4192      US Navy      LC-18A, Cape Canaveral AFS, Florida, USA
# 4193    RVSN USSR     Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4194    RVSN USSR     Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                                             Detail  Status Rocket  Rocket  \
# 0     Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.0
# ...

# %%
global_launches_df= global_launches_df.drop(labels=['DateTime', 'Year', 'Month', 'Day'], axis=1)
global_launches_df
# Out:
#      Company Name                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1           CASIC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                                             Detail  Status Rocket  Rocket  \
# ...

# %%
spacemissions_df
# Out:
#      Company Name                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                            Datum  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# ...

# %%
foo = lambda x: pd.Series([i for i in reversed(x.split(' '))])
rev = spacemissions_df['Datum'].apply(foo)
print(rev)
# Out:
#         0      1     2    3    4    5
# 0     UTC  05:12  2020  07,  Aug  Fri
# 1     UTC  04:01  2020  06,  Aug  Thu
# 2     UTC  23:57  2020  04,  Aug  Tue
# 3     UTC  21:25  2020  30,  Jul  Thu
# 4     UTC  11:50  2020  30,  Jul  Thu
# ...   ...    ...   ...  ...  ...  ...
# 4319  UTC  07:33  1958  05,  Feb  Wed
# 4320  UTC  03:48  1958  01,  Feb  Sat
# 4321  UTC  16:44  1957  06,  Dec  Fri
# 4322  UTC  02:30  1957  03,  Nov  Sun
# 4323  UTC  19:28  1957  04,  Oct  Fri
#
# [4324 rows x 6 columns]

# %%
rev.rename(columns={0:'Zone',1:'Time',2:'Year',3:'Day',4:'Month',5:'Weekday'},inplace=True)

print(rev)
# Out:
#      Zone   Time  Year  Day Month Weekday
# 0     UTC  05:12  2020  07,   Aug     Fri
# 1     UTC  04:01  2020  06,   Aug     Thu
# 2     UTC  23:57  2020  04,   Aug     Tue
# 3     UTC  21:25  2020  30,   Jul     Thu
# 4     UTC  11:50  2020  30,   Jul     Thu
# ...   ...    ...   ...  ...   ...     ...
# 4319  UTC  07:33  1958  05,   Feb     Wed
# 4320  UTC  03:48  1958  01,   Feb     Sat
# 4321  UTC  16:44  1957  06,   Dec     Fri
# 4322  UTC  02:30  1957  03,   Nov     Sun
# 4323  UTC  19:28  1957  04,   Oct     Fri
#
# [4324 rows x 6 columns]

# %%
spacemissions_df
# Out:
#      Company Name                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                            Datum  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# ...
